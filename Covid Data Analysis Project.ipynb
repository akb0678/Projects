# %% [markdown]
# Title: Problem for Covid - 19 Data Analysis Project using Python
# Dataset link :
# Url = https://raw.githubusercontent.com/SR1608/Datasets/main/coviddata.csv
# Perform following analysis on above dataset :

# %% [markdown]
# 1. Import the dataset using Pandas from above mentioned url.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
covid = pd.read_csv('https://raw.githubusercontent.com/SR1608/Datasets/main/covid-data.csv')
covid.head()
# Out:
#   iso_code continent     location      date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  31/12/19          NaN        0.0
# 1      AFG      Asia  Afghanistan  01/01/20          NaN        0.0
# 2      AFG      Asia  Afghanistan  02/01/20          NaN        0.0
# 3      AFG      Asia  Afghanistan  03/01/20          NaN        0.0
# 4      AFG      Asia  Afghanistan  04/01/20          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %% [markdown]
# 2. High Level Data Understanding:
# a. Find no. of rows & columns in the dataset
# b. Data types of columns.
# c. Info & describe of data in dataframe.

# %% [markdown]
# a. Find no. of rows & columns in the dataset

# %%
print(f"Number of rows = {covid.shape[0]}")
print(f"Number of columns = {covid.shape[1]}")
# Out:
# Number of rows = 57394
# Number of columns = 49

# %% [markdown]
# b. Data types of columns.

# %%
print(f"Data types = \n{covid.dtypes}")
# Out:
# Data types =
# iso_code                               object
# continent                              object
# location                               object
# date                                   object
# total_cases                           float64
# new_cases                             float64
# new_cases_smoothed                    float64
# total_deaths                          float64
# new_deaths                            float64
# new_deaths_smoothed                   float64
# total_cases_per_million               float64
# new_cases_per_million                 float64
# new_cases_smoothed_per_million        float64
# total_deaths_per_million              float64
# new_deaths_per_million                float64
# new_deaths_smoothed_per_million       float64
# reproduction_rate                     float64
# icu_patients                          float64
# icu_patients_per_million              float64
# hosp_patients                         float64
# ...

# %% [markdown]
# c. Info & describe of data in dataframe.

# %%
covid.info
# Out:
# <bound method DataFrame.info of       iso_code continent       location      date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  31/12/19          NaN        0.0
# 1          AFG      Asia    Afghanistan  01/01/20          NaN        0.0
# 2          AFG      Asia    Afghanistan  02/01/20          NaN        0.0
# 3          AFG      Asia    Afghanistan  03/01/20          NaN        0.0
# 4          AFG      Asia    Afghanistan  04/01/20          NaN        0.0
# ...        ...       ...            ...       ...          ...        ...
# 57389      NaN       NaN  International  13/11/20        696.0        NaN
# 57390      NaN       NaN  International  14/11/20        696.0        NaN
# 57391      NaN       NaN  International  15/11/20        696.0        NaN
# 57392      NaN       NaN  International  16/11/20        696.0        NaN
# 57393      NaN       NaN  International  17/11/20        696.0        NaN
#
# ...

# %% [markdown]
# covid.describe()

# %% [markdown]
# 3. Low Level Data Understanding :
#  a. Find count of unique values in location column.
#  b. Find which continent has maximum frequency using values
# counts.
#  c. Find maximum & mean value in 'total_cases'.
#  d. Find 25%,50% & 75% quartile value in 'total_deaths'.
#  e. Find which continent has maximum
# 'human_development_index'.
#  f. Find which continent has minimum 'gdp_per_capita'

# %% [markdown]
# a. Find count of unique values in location column.

# %%
print(f"Count of unique values = {covid['location'].nunique()}")
# Out:
# Count of unique values = 216

# %%
# Approach 2
print(f"Count of Unique Values = {len(covid['location'].value_counts())}")
# Out:
# Count of Unique Values = 216

# %% [markdown]
# b. Find which continent has maximum frequency using values
# counts.

# %%
print(f"Continent having maximum frequency = {covid['continent'].value_counts().idxmax()}")
# Out:
# Continent having maximum frequency = Europe

# %% [markdown]
# c. Find maximum & mean value in 'total_cases'.

# %%
t_max=covid['total_cases'].max()
t_mean=covid['total_cases'].mean()
print(f"Maximum value : {t_max}")
print(f"Mean value : {t_mean}")
# Out:
# Maximum value : 55154651.0
# Mean value : 167797.3688753302

# %% [markdown]
# d. Find 25%,50% & 75% quartile value in 'total_deaths'.

# %%
print(f"Quartile value of 25%,50%,75% : {covid['total_deaths'].quantile([0.25,0.50,0.75])}")
# Out:
# Quartile value of 25%,50%,75% : 0.25     13.0
# 0.50     84.0
# 0.75    727.0
# Name: total_deaths, dtype: float64

# %% [markdown]
#  e. Find which continent has maximum 'human_development_index'.

# %%
covid.groupby('continent')['human_development_index'].max().idxmax()
# Out:
# 'Europe'

# %% [markdown]
#  f. Find which continent has minimum 'gdp_per_capita'.

# %%
covid.groupby('continent')['gdp_per_capita'].min().idxmin()
# Out:
# 'Africa'

# %% [markdown]
# 4. Filter the dataframe with only this columns
# ['continent','location','date','total_cases','total_deaths','gdp_per_ca
# pita','
# human_development_index'] and update the data frame.

# %%
covid_1=covid[['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index']]
covid_1
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          NaN           NaN
# 1          Asia    Afghanistan  01/01/20          NaN           NaN
# 2          Asia    Afghanistan  02/01/20          NaN           NaN
# 3          Asia    Afghanistan  03/01/20          NaN           NaN
# 4          Asia    Afghanistan  04/01/20          NaN           NaN
# ...         ...            ...       ...          ...           ...
# 57389       NaN  International  13/11/20        696.0           7.0
# 57390       NaN  International  14/11/20        696.0           7.0
# 57391       NaN  International  15/11/20        696.0           7.0
# 57392       NaN  International  16/11/20        696.0           7.0
# 57393       NaN  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %% [markdown]
# 5. Data Cleaning
#  a. Remove all duplicates observations
#  b. Find missing values in all columns
#  c. Remove all observations where continent column value is
# missing
#  Tip : using subset parameter in dropna
#  d. Fill all missing values with 0

# %% [markdown]
# a. Remove all duplicates observations

# %%
covid.drop_duplicates()
# Out:
#       iso_code continent       location      date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  31/12/19          NaN        0.0
# 1          AFG      Asia    Afghanistan  01/01/20          NaN        0.0
# 2          AFG      Asia    Afghanistan  02/01/20          NaN        0.0
# 3          AFG      Asia    Afghanistan  03/01/20          NaN        0.0
# 4          AFG      Asia    Afghanistan  04/01/20          NaN        0.0
# ...        ...       ...            ...       ...          ...        ...
# 57389      NaN       NaN  International  13/11/20        696.0        NaN
# 57390      NaN       NaN  International  14/11/20        696.0        NaN
# 57391      NaN       NaN  International  15/11/20        696.0        NaN
# 57392      NaN       NaN  International  16/11/20        696.0        NaN
# 57393      NaN       NaN  International  17/11/20        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
covid_1.drop_duplicates()
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          NaN           NaN
# 1          Asia    Afghanistan  01/01/20          NaN           NaN
# 2          Asia    Afghanistan  02/01/20          NaN           NaN
# 3          Asia    Afghanistan  03/01/20          NaN           NaN
# 4          Asia    Afghanistan  04/01/20          NaN           NaN
# ...         ...            ...       ...          ...           ...
# 57389       NaN  International  13/11/20        696.0           7.0
# 57390       NaN  International  14/11/20        696.0           7.0
# 57391       NaN  International  15/11/20        696.0           7.0
# 57392       NaN  International  16/11/20        696.0           7.0
# 57393       NaN  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %% [markdown]
#  b. Find missing values in all columns

# %%
# Approach 1
# Type 1
covid.isnull().sum()
# Out:
# iso_code                                323
# continent                               646
# location                                  0
# date                                      0
# total_cases                            3636
# new_cases                               929
# new_cases_smoothed                     1742
# total_deaths                          13026
# new_deaths                              929
# new_deaths_smoothed                    1742
# total_cases_per_million                3923
# new_cases_per_million                   993
# new_cases_smoothed_per_million         1807
# total_deaths_per_million              13298
# new_deaths_per_million                  993
# new_deaths_smoothed_per_million        1807
# reproduction_rate                     19698
# icu_patients                          52904
# icu_patients_per_million              52904
# hosp_patients                         52389
# hosp_patients_per_million             52389
# ...

# %%
# Type 2
covid.isna().sum()
# Out:
# iso_code                                323
# continent                               646
# location                                  0
# date                                      0
# total_cases                            3636
# new_cases                               929
# new_cases_smoothed                     1742
# total_deaths                          13026
# new_deaths                              929
# new_deaths_smoothed                    1742
# total_cases_per_million                3923
# new_cases_per_million                   993
# new_cases_smoothed_per_million         1807
# total_deaths_per_million              13298
# new_deaths_per_million                  993
# new_deaths_smoothed_per_million        1807
# reproduction_rate                     19698
# icu_patients                          52904
# icu_patients_per_million              52904
# hosp_patients                         52389
# hosp_patients_per_million             52389
# ...

# %%
# Approach 2
# Type 1
covid_1.isnull().sum()
# Out:
# continent                    646
# location                       0
# date                           0
# total_cases                 3636
# total_deaths               13026
# gdp_per_capita              7027
# human_development_index     8147
# dtype: int64

# %%
# Type 2
covid_1.isna().sum()
# Out:
# continent                    646
# location                       0
# date                           0
# total_cases                 3636
# total_deaths               13026
# gdp_per_capita              7027
# human_development_index     8147
# dtype: int64

# %% [markdown]
#  c. Remove all observations where continent column value is
# missing

# %%
covid_0=covid.copy()
covid_0=covid_0.dropna(subset=['continent'],how='all')
covid_0
# Out:
#       iso_code continent     location      date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  31/12/19          NaN        0.0
# 1          AFG      Asia  Afghanistan  01/01/20          NaN        0.0
# 2          AFG      Asia  Afghanistan  02/01/20          NaN        0.0
# 3          AFG      Asia  Afghanistan  03/01/20          NaN        0.0
# 4          AFG      Asia  Afghanistan  04/01/20          NaN        0.0
# ...        ...       ...          ...       ...          ...        ...
# 56743      ZWE    Africa     Zimbabwe  13/11/20       8696.0       29.0
# 56744      ZWE    Africa     Zimbabwe  14/11/20       8765.0       69.0
# 56745      ZWE    Africa     Zimbabwe  15/11/20       8786.0       21.0
# 56746      ZWE    Africa     Zimbabwe  16/11/20       8786.0        0.0
# 56747      ZWE    Africa     Zimbabwe  17/11/20       8897.0      111.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %% [markdown]
# d. Fill all missing values with 0

# %%
covid_0=covid_0.fillna(0)
covid_0
# Out:
#       iso_code continent     location      date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  31/12/19          0.0        0.0
# 1          AFG      Asia  Afghanistan  01/01/20          0.0        0.0
# 2          AFG      Asia  Afghanistan  02/01/20          0.0        0.0
# 3          AFG      Asia  Afghanistan  03/01/20          0.0        0.0
# 4          AFG      Asia  Afghanistan  04/01/20          0.0        0.0
# ...        ...       ...          ...       ...          ...        ...
# 56743      ZWE    Africa     Zimbabwe  13/11/20       8696.0       29.0
# 56744      ZWE    Africa     Zimbabwe  14/11/20       8765.0       69.0
# 56745      ZWE    Africa     Zimbabwe  15/11/20       8786.0       21.0
# 56746      ZWE    Africa     Zimbabwe  16/11/20       8786.0        0.0
# 56747      ZWE    Africa     Zimbabwe  17/11/20       8897.0      111.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %% [markdown]
# 6. Date time format :
#  a. Convert date column in datetime format using
# pandas.to_datetime
# b. Create new column month after extracting month data from
# date
#  column.

# %%
covid['date'] = pd.to_datetime(covid['date'])

# %%
covid.dtypes
# Out:
# iso_code                                      object
# continent                                     object
# location                                      object
# date                                  datetime64[ns]
# total_cases                                  float64
# new_cases                                    float64
# new_cases_smoothed                           float64
# total_deaths                                 float64
# new_deaths                                   float64
# new_deaths_smoothed                          float64
# total_cases_per_million                      float64
# new_cases_per_million                        float64
# new_cases_smoothed_per_million               float64
# total_deaths_per_million                     float64
# new_deaths_per_million                       float64
# new_deaths_smoothed_per_million              float64
# reproduction_rate                            float64
# icu_patients                                 float64
# ...

# %% [markdown]
# b. Create new column month after extracting month data from
# date
#  column.

# %%
covid['Month'] = pd.DatetimeIndex(covid['date']).month
covid.head()
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan 2019-12-31          NaN        0.0
# 1      AFG      Asia  Afghanistan 2020-01-01          NaN        0.0
# 2      AFG      Asia  Afghanistan 2020-02-01          NaN        0.0
# 3      AFG      Asia  Afghanistan 2020-03-01          NaN        0.0
# 4      AFG      Asia  Afghanistan 2020-04-01          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# ...

# %% [markdown]
# 7. Data Aggregation:
#  a. Find max value in all columns using groupby function on
# 'continent'
#  column
#  Tip: use reset_index() after applying groupby
#  b. Store the result in a new dataframe named 'df_groupby'.
#  (Use df_groupby dataframe for all further analysis)

# %% [markdown]
# a. Find max value in all columns using groupby function on
# 'continent'
#  column
#  Tip: use reset_index() after applying groupby

# %%
covid_agg= covid.copy()
covid_agg = covid_agg.groupby('continent').max().reset_index()
covid_agg
# Out:
#        continent iso_code                      location       date  \
# 0         Africa      ZWE                      Zimbabwe 2020-12-11
# 1           Asia      YEM                         Yemen 2020-12-11
# 2         Europe      VAT                       Vatican 2020-12-11
# 3  North America      VIR  United States Virgin Islands 2020-12-11
# 4        Oceania      WLF             Wallis and Futuna 2020-12-11
# 5  South America      VEN                     Venezuela 2020-12-11
#
#    total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0     752269.0    13944.0           12583.714       20314.0       572.0
# 1    8874290.0    97894.0           93198.571      130519.0      2003.0
# 2    1991233.0    86852.0           54868.571       52147.0      2004.0
# 3   11205486.0   184813.0          156419.143      247220.0      4928.0
# 4      27750.0     1384.0             551.714         907.0        59.0
# ...

# %% [markdown]
#  b. Store the result in a new dataframe named 'df_groupby'.
#  (Use df_groupby dataframe for all further analysis)

# %%
df_groupby = covid_agg.copy()
df_groupby.head()
# Out:
#        continent iso_code                      location       date  \
# 0         Africa      ZWE                      Zimbabwe 2020-12-11
# 1           Asia      YEM                         Yemen 2020-12-11
# 2         Europe      VAT                       Vatican 2020-12-11
# 3  North America      VIR  United States Virgin Islands 2020-12-11
# 4        Oceania      WLF             Wallis and Futuna 2020-12-11
#
#    total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0     752269.0    13944.0           12583.714       20314.0       572.0
# 1    8874290.0    97894.0           93198.571      130519.0      2003.0
# 2    1991233.0    86852.0           54868.571       52147.0      2004.0
# 3   11205486.0   184813.0          156419.143      247220.0      4928.0
# 4      27750.0     1384.0             551.714         907.0        59.0
#
#    new_deaths_smoothed  ...  extreme_poverty  cardiovasc_death_rate  \
# ...

# %% [markdown]
# 8. Feature Engineering :
#  a. Create a new feature 'total_deaths_to_total_cases' by ratio of
#  'total_deaths' column to 'total_cases'

# %%
df_groupby['total_deaths_to_total_cases'] = df_groupby['total_deaths'] / df_groupby['total_cases']
df_groupby['total_deaths_to_total_cases']
# Out:
# 0    0.027004
# 1    0.014708
# 2    0.026188
# 3    0.022062
# 4    0.032685
# 5    0.028251
# Name: total_deaths_to_total_cases, dtype: float64

# %% [markdown]
# 9. Data Visualization :
#  a. Perform Univariate analysis on 'gdp_per_capita' column by
# plotting
#  histogram using seaborn dist plot.
#  b. Plot a scatter plot of 'total_cases' & 'gdp_per_capita'
#  c. Plot Pairplot on df_groupby dataset.
#  d. Plot a bar plot of 'continent' column with 'total_cases' .
#  Tip : using kind='bar' in seaborn catplot

# %% [markdown]
# a. Perform Univariate analysis on 'gdp_per_capita' column by
# plotting

# %%
plt.figure(figsize=(10,10))
sns.set()
sns.distplot(x=df_groupby['gdp_per_capita'],label="GDP_Per_Capita",color="blue", bins=25)
plt.title('Histogram of GDP_Per_Capita')
plt.legend()
# Out:
# C:\Users\91898\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Approach Without using df_groupby
plt.figure(figsize=(10,10))
sns.set()
sns.distplot(x=covid['gdp_per_capita'],label="GDP_Per_Capita",color="blue", bins=25)
plt.title('Histogram of GDP_Per_Capita')
plt.legend()
# Out:
# C:\Users\91898\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# b. Plot a scatter plot of 'total_cases' & 'gdp_per_capita'

# %%
# Approach by using df_groupby
plt.figure(figsize=(12,9))
sns.set()
sns.scatterplot(x=df_groupby['total_cases'], y=df_groupby['gdp_per_capita'],s=200, edgecolor = 'g', linewidth = 10)
plt.xlabel('Total_Cases')
plt.ylabel('GDP_Per_Capita')
plt.title('Total Cases Upon GDP_Per_Capita')
plt.show()

# %%
# Approach without using df_groupby
plt.figure(figsize=(12,9))
sns.set()
sns.scatterplot(x=covid['total_cases'], y=covid['gdp_per_capita'],s=200, edgecolor = 'g', linewidth = 10)
plt.xlabel('Total_Cases')
plt.ylabel('GDP_Per_Capita')
plt.title('Total Cases Upon GDP_Per_Capita')
plt.show()

# %% [markdown]
#  c. Plot Pairplot on df_groupby dataset.

# %%
sns.pairplot(df_groupby,vars=['gdp_per_capita','total_cases',
'total_deaths',],palette= 'BrBG')
plt.show()

# %% [markdown]
# d. Plot a bar plot of 'continent' column with 'total_cases' .
#  Tip : using kind='bar' in seaborn catplot

# %%
# approach 1
sns.set()
plt.figure(figsize=(16,9))
sns.catplot(x='continent',y='total_cases',data=df_groupby,kind='strip')
plt.xlabel('Cotinent')
plt.ylabel('Total Cases')
plt.title('Total Cases on Different Continent')
plt.show()

# %%
# approach 2
sns.set()
plt.figure(figsize=(16,9))
sns.barplot(x='continent',y='total_cases',data=df_groupby)
plt.xlabel('Cotinent')
plt.ylabel('Total Cases')
plt.title('Total Cases on Different Continent')
plt.show()

# %% [markdown]
# 10.Save the df_groupby dataframe in your local drive using
# pandas.to_csv
#  function

# %%
df_groupby.to_csv("C:/Users/91898/Downloads/covid_analysis.csv",index=False)
